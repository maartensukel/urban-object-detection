# %%
from garbage_detection import GarbageImageClassifier
from IPython.display import Image

GarbageImageClassifier = GarbageImageClassifier(cuda=True)
# Out:
# Loading network...
# 2019-10-29 14:11:08,140 garbage_detection INFO GarbageImageClassifier: Init
# 2019-10-29 14:11:08,140 garbage_detection INFO GarbageImageClassifier: Init
# Network loaded

# %%
print('single image')

path = './samples/input5_frame11.jpg'
attributes = GarbageImageClassifier.detect_image(path)

print()
print(attributes)

print()
print(attributes[0]['counts'])

Image(path)
# Out:
# single image
# Loading input image(s)...
# Input image(s) loaded
# Detecting...
# Detection finished in 0:00:00.105193
#
# [{'image_meta': {'width': 416, 'height': 416}, 'boxes': [{'class': 'garbage_bag', 'confidence': 99, 'coordinate1': [1707, 98], 'coordinate2': [1731, 139]}, {'class': 'garbage_bag', 'confidence': 88, 'coordinate1': [1634, 104], 'coordinate2': [1669, 145]}, {'class': 'garbage_bag', 'confidence': 99, 'coordinate1': [777, 345], 'coordinate2': [919, 522]}, {'class': 'garbage_bag', 'confidence': 99, 'coordinate1': [1671, 105], 'coordinate2': [1696, 147]}, {'class': 'garbage_bag', 'confidence': 99, 'coordinate1': [1740, 83], 'coordinate2': [1759, 134]}], 'counts': {'container_small': 0, 'garbage_bag': 5, 'cardboard': 0, 'total': 5}}]
#
# {'container_small': 0, 'garbage_bag': 5, 'cardboard': 0, 'total': 5}
# ...

# %%
print('multiple image')

path = './samples/'
attributes = GarbageImageClassifier.detect_image(path)

print()
print(attributes)
# Out:
# multiple image
# Loading input image(s)...
# Input image(s) loaded
# Detecting...
# /home/maarten/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:2479: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Detection finished in 0:00:01.323276
#
# ...
